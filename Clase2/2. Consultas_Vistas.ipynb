-- %%
%sql
use catalog_dev.bronze;

-- %%
%sql
select current_catalog(),current_database()

-- %%
-- Consulta view persistente
select * from workspace.default.empleados_fltrados_tmp

-- %%
drop view empleados_fltrados

-- %%
show views in workspace.default;

-- %%
-- Consulta view temporal
select * from empleados_fltrados_tmp
