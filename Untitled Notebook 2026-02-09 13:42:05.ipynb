# %%
dbutils.secrets.listScopes()

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@adstlakedemo.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas delta del Data bronze';

# %%
df = spark.read.csv("abfss://bronze@adstlakedemo.dfs.core.windows.net/olist_products_dataset.csv", header=True)
display(df)
